# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000,size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Import citipy to obtain cities from lat and long
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 568

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2075a61b97e9dfc66fa3ba5f897a45dc

# %%
# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Records {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

 # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_currweather = city_weather["weather"][0]["description"]
        try:
            city_rain = city_weather["rain"]["3h"]
        except:
            city_rain = 0
        try: 
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Rain (inches, last 3 hrs)": city_rain,
                          "Snow (inches, last 3 hrs)": city_snow,
                          "Current Weather Description": city_currweather,
                          "Country": city_country,
                          "Date": city_date})
        
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete
print("----------------------------")
print("Data Retrieval Complete     ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Records 1 of Set 1 | cape town
# Processing Records 2 of Set 1 | hovd
# Processing Records 3 of Set 1 | hobart
# Processing Records 4 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Records 5 of Set 1 | marsa matruh
# Processing Records 6 of Set 1 | vaini
# Processing Records 7 of Set 1 | esperance
# Processing Records 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Records 9 of Set 1 | new norfolk
# Processing Records 10 of Set 1 | harbour breton
# Processing Records 11 of Set 1 | punta arenas
# Processing Records 12 of Set 1 | mahebourg
# Processing Records 13 of Set 1 | mataura
# Processing Records 14 of Set 1 | atbasar
# Processing Records 15 of Set 1 | guerrero negro
# Processing Records 16 of Set 1 | kodiak
# Processing Records 17 of Set 1 | ushuaia
# Processing Records 18 of Set 1 | honiara
# Processing Records 19 of Set 1 | tuatapere
# Processing Records 20 of Set 1 | karratha
# Processing Records 21 of Set 1 | kyaikkami
# Processing Records 22 of Set 1 | caravelas
# Processing Records 23 of Set 1 | busselton
# Processing Records 24 of Set 1 | werda
# Processing Records 25 of Set 1 | thompson
# Processing Records 26 of Set 1 | hoquiam
# Processing Records 27 of Set 1 | lolua
# City not found. Skipping...
# Processing Records 28 of Set 1 | provideniya
# Processing Records 29 of Set 1 | puerto ayora
# Processing Records 30 of Set 1 | sur
# Processing Records 31 of Set 1 | cidreira
# Processing Records 32 of Set 1 | muravlenko
# Processing Records 33 of Set 1 | tiksi
# Processing Records 34 of Set 1 | tabou
# Processing Records 35 of Set 1 | qaanaaq
# Processing Records 36 of Set 1 | ilulissat
# Processing Records 37 of Set 1 | ust-omchug
# Processing Records 38 of Set 1 | qaqortoq
# Processing Records 39 of Set 1 | armasesti
# Processing Records 40 of Set 1 | clearwater
# Processing Records 41 of Set 1 | victoria
# Processing Records 42 of Set 1 | quatre cocos
# Processing Records 43 of Set 1 | yellowknife
# Processing Records 44 of Set 1 | lukulu
# Processing Records 45 of Set 1 | albany
# Processing Records 46 of Set 1 | kaseda
# Processing Records 47 of Set 1 | savannah bight
# Processing Records 48 of Set 1 | georgetown
# Processing Records 49 of Set 1 | ambilobe
# Processing Records 50 of Set 1 | north bend
# Processing Records 1 of Set 2 | warqla
# City not found. Skipping...
# Processing Records 2 of Set 2 | severo-kurilsk
# Processing Records 3 of Set 2 | bluff
# Processing Records 4 of Set 2 | san cristobal
# Processing Records 5 of Set 2 | olafsvik
# Processing Records 6 of Set 2 | ayagoz
# Processing Records 7 of Set 2 | george
# Processing Records 8 of Set 2 | arraial do cabo
# Processing Records 9 of Set 2 | we
# City not found. Skipping...
# Processing Records 10 of Set 2 | kavaratti
# Processing Records 11 of Set 2 | linxia
# Processing Records 12 of Set 2 | saquarema
# Processing Records 13 of Set 2 | wajid
# Processing Records 14 of Set 2 | faanui
# Processing Records 15 of Set 2 | meulaboh
# Processing Records 16 of Set 2 | kruisfontein
# Processing Records 17 of Set 2 | artyom
# Processing Records 18 of Set 2 | grindavik
# Processing Records 19 of Set 2 | pamanukan
# Processing Records 20 of Set 2 | tanabe
# Processing Records 21 of Set 2 | flinders
# Processing Records 22 of Set 2 | upernavik
# Processing Records 23 of Set 2 | rikitea
# Processing Records 24 of Set 2 | khatanga
# Processing Records 25 of Set 2 | saleaula
# City not found. Skipping...
# Processing Records 26 of Set 2 | mehamn
# Processing Records 27 of Set 2 | sitka
# Processing Records 28 of Set 2 | iqaluit
# Processing Records 29 of Set 2 | lavrentiya
# Processing Records 30 of Set 2 | bethel
# Processing Records 31 of Set 2 | poltavka
# Processing Records 32 of Set 2 | palauig
# Processing Records 33 of Set 2 | at-bashi
# Processing Records 34 of Set 2 | nemuro
# Processing Records 35 of Set 2 | hihifo
# City not found. Skipping...
# Processing Records 36 of Set 2 | lamu
# Processing Records 37 of Set 2 | weihai
# Processing Records 38 of Set 2 | hami
# Processing Records 39 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Records 40 of Set 2 | avarua
# Processing Records 41 of Set 2 | amderma
# City not found. Skipping...
# Processing Records 42 of Set 2 | vung tau
# Processing Records 43 of Set 2 | yerofey pavlovich
# Processing Records 44 of Set 2 | nelson bay
# Processing Records 45 of Set 2 | sabha
# Processing Records 46 of Set 2 | salalah
# Processing Records 47 of Set 2 | salinopolis
# Processing Records 48 of Set 2 | hermanus
# Processing Records 49 of Set 2 | namalenga
# Processing Records 50 of Set 2 | aklavik
# Processing Records 1 of Set 3 | belyy yar
# Processing Records 2 of Set 3 | laguna
# Processing Records 3 of Set 3 | touros
# Processing Records 4 of Set 3 | tangua
# Processing Records 5 of Set 3 | naze
# Processing Records 6 of Set 3 | sobolevo
# Processing Records 7 of Set 3 | narsaq
# Processing Records 8 of Set 3 | norman wells
# Processing Records 9 of Set 3 | kapaa
# Processing Records 10 of Set 3 | hasaki
# Processing Records 11 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Records 12 of Set 3 | takoradi
# Processing Records 13 of Set 3 | markova
# Processing Records 14 of Set 3 | watertown
# Processing Records 15 of Set 3 | taoudenni
# Processing Records 16 of Set 3 | port elizabeth
# Processing Records 17 of Set 3 | angoche
# Processing Records 18 of Set 3 | tuktoyaktuk
# Processing Records 19 of Set 3 | souillac
# Processing Records 20 of Set 3 | folldal
# Processing Records 21 of Set 3 | atuona
# Processing Records 22 of Set 3 | saint-pierre
# Processing Records 23 of Set 3 | calvinia
# Processing Records 24 of Set 3 | barrow
# Processing Records 25 of Set 3 | los llanos de aridane
# Processing Records 26 of Set 3 | santo antonio do amparo
# Processing Records 27 of Set 3 | tasiilaq
# Processing Records 28 of Set 3 | alice springs
# Processing Records 29 of Set 3 | kahului
# Processing Records 30 of Set 3 | hamilton
# Processing Records 31 of Set 3 | biak
# Processing Records 32 of Set 3 | yerbogachen
# Processing Records 33 of Set 3 | boa vista
# Processing Records 34 of Set 3 | castro
# Processing Records 35 of Set 3 | jamestown
# Processing Records 36 of Set 3 | east london
# Processing Records 37 of Set 3 | port alfred
# Processing Records 38 of Set 3 | mopti
# Processing Records 39 of Set 3 | chapais
# Processing Records 40 of Set 3 | vincennes
# Processing Records 41 of Set 3 | dikson
# Processing Records 42 of Set 3 | sorland
# Processing Records 43 of Set 3 | carnarvon
# Processing Records 44 of Set 3 | bambous virieux
# Processing Records 45 of Set 3 | goderich
# Processing Records 46 of Set 3 | walvis bay
# Processing Records 47 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Records 48 of Set 3 | leshukonskoye
# Processing Records 49 of Set 3 | canon city
# Processing Records 50 of Set 3 | rocha
# Processing Records 1 of Set 4 | dudinka
# Processing Records 2 of Set 4 | saint-philippe
# Processing Records 3 of Set 4 | katsuura
# Processing Records 4 of Set 4 | ust-maya
# Processing Records 5 of Set 4 | kamenka
# Processing Records 6 of Set 4 | zharkovskiy
# Processing Records 7 of Set 4 | pastavy
# Processing Records 8 of Set 4 | sisimiut
# Processing Records 9 of Set 4 | along
# Processing Records 10 of Set 4 | dingle
# Processing Records 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Records 12 of Set 4 | adrar
# Processing Records 13 of Set 4 | yatou
# Processing Records 14 of Set 4 | bubaque
# Processing Records 15 of Set 4 | pisco
# Processing Records 16 of Set 4 | floro
# Processing Records 17 of Set 4 | beloha
# Processing Records 18 of Set 4 | buala
# Processing Records 19 of Set 4 | butaritari
# Processing Records 20 of Set 4 | ojinaga
# Processing Records 21 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Records 22 of Set 4 | kaitangata
# Processing Records 23 of Set 4 | xining
# Processing Records 24 of Set 4 | baghdad
# Processing Records 25 of Set 4 | luderitz
# Processing Records 26 of Set 4 | saint george
# Processing Records 27 of Set 4 | saldanha
# Processing Records 28 of Set 4 | samusu
# City not found. Skipping...
# Processing Records 29 of Set 4 | petatlan
# Processing Records 30 of Set 4 | ribeira grande
# Processing Records 31 of Set 4 | luganville
# Processing Records 32 of Set 4 | puerto madero
# Processing Records 33 of Set 4 | hurghada
# Processing Records 34 of Set 4 | vossevangen
# Processing Records 35 of Set 4 | hilo
# Processing Records 36 of Set 4 | uige
# Processing Records 37 of Set 4 | cedar city
# Processing Records 38 of Set 4 | vila
# Processing Records 39 of Set 4 | wismar
# Processing Records 40 of Set 4 | verkh-usugli
# Processing Records 41 of Set 4 | atar
# Processing Records 42 of Set 4 | aleysk
# Processing Records 43 of Set 4 | porbandar
# Processing Records 44 of Set 4 | cherskiy
# Processing Records 45 of Set 4 | port hardy
# Processing Records 46 of Set 4 | nikolskoye
# Processing Records 47 of Set 4 | dzaoudzi
# Processing Records 48 of Set 4 | lasa
# Processing Records 49 of Set 4 | abnub
# Processing Records 50 of Set 4 | namibe
# Processing Records 1 of Set 5 | sao joao da barra
# Processing Records 2 of Set 5 | hirara
# Processing Records 3 of Set 5 | ust-kuyga
# Processing Records 4 of Set 5 | kimbe
# Processing Records 5 of Set 5 | bredasdorp
# Processing Records 6 of Set 5 | marcona
# City not found. Skipping...
# Processing Records 7 of Set 5 | college
# Processing Records 8 of Set 5 | kiunga
# Processing Records 9 of Set 5 | ponta do sol
# Processing Records 10 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Records 11 of Set 5 | vallenar
# Processing Records 12 of Set 5 | jaisalmer
# Processing Records 13 of Set 5 | meyungs
# City not found. Skipping...
# Processing Records 14 of Set 5 | salacgriva
# Processing Records 15 of Set 5 | minab
# Processing Records 16 of Set 5 | nanortalik
# Processing Records 17 of Set 5 | chokurdakh
# Processing Records 18 of Set 5 | praia
# Processing Records 19 of Set 5 | wajir
# Processing Records 20 of Set 5 | chuy
# Processing Records 21 of Set 5 | ashland
# Processing Records 22 of Set 5 | pimentel
# Processing Records 23 of Set 5 | shingu
# Processing Records 24 of Set 5 | longyearbyen
# Processing Records 25 of Set 5 | jabiru
# City not found. Skipping...
# Processing Records 26 of Set 5 | bereda
# Processing Records 27 of Set 5 | namatanai
# Processing Records 28 of Set 5 | magura ilvei
# Processing Records 29 of Set 5 | nicoya
# Processing Records 30 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Records 31 of Set 5 | sept-iles
# Processing Records 32 of Set 5 | paamiut
# Processing Records 33 of Set 5 | kitui
# Processing Records 34 of Set 5 | fairbanks
# Processing Records 35 of Set 5 | santa cruz
# Processing Records 36 of Set 5 | lebu
# Processing Records 37 of Set 5 | flin flon
# Processing Records 38 of Set 5 | chaman
# Processing Records 39 of Set 5 | nalobikha
# Processing Records 40 of Set 5 | trairi
# Processing Records 41 of Set 5 | oksfjord
# Processing Records 42 of Set 5 | egvekinot
# Processing Records 43 of Set 5 | mar del plata
# Processing Records 44 of Set 5 | leh
# Processing Records 45 of Set 5 | bengkulu
# Processing Records 46 of Set 5 | virginia beach
# Processing Records 47 of Set 5 | aloleng
# Processing Records 48 of Set 5 | eureka
# Processing Records 49 of Set 5 | savelugu
# Processing Records 50 of Set 5 | chagda
# City not found. Skipping...
# Processing Records 1 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Records 2 of Set 6 | bambanglipuro
# Processing Records 3 of Set 6 | veinticinco de mayo
# Processing Records 4 of Set 6 | faya
# Processing Records 5 of Set 6 | wagar
# Processing Records 6 of Set 6 | turukhansk
# Processing Records 7 of Set 6 | nuuk
# Processing Records 8 of Set 6 | silopi
# Processing Records 9 of Set 6 | bathsheba
# Processing Records 10 of Set 6 | kulhudhuffushi
# Processing Records 11 of Set 6 | palu
# Processing Records 12 of Set 6 | vuktyl
# Processing Records 13 of Set 6 | hithadhoo
# Processing Records 14 of Set 6 | noumea
# Processing Records 15 of Set 6 | saint-andre-avellin
# Processing Records 16 of Set 6 | damara
# Processing Records 17 of Set 6 | lethem
# Processing Records 18 of Set 6 | saint-joseph
# Processing Records 19 of Set 6 | labytnangi
# Processing Records 20 of Set 6 | sola
# Processing Records 21 of Set 6 | dauphin
# Processing Records 22 of Set 6 | hofn
# Processing Records 23 of Set 6 | mabaruma
# Processing Records 24 of Set 6 | portland
# Processing Records 25 of Set 6 | port macquarie
# Processing Records 26 of Set 6 | san nicolas
# Processing Records 27 of Set 6 | taungdwingyi
# Processing Records 28 of Set 6 | atikokan
# Processing Records 29 of Set 6 | hobyo
# Processing Records 30 of Set 6 | kansk
# Processing Records 31 of Set 6 | mahanoro
# Processing Records 32 of Set 6 | quelimane
# Processing Records 33 of Set 6 | karachi
# Processing Records 34 of Set 6 | acapulco
# Processing Records 35 of Set 6 | riyadh
# Processing Records 36 of Set 6 | whitecourt
# Processing Records 37 of Set 6 | hendek
# Processing Records 38 of Set 6 | kaeo
# Processing Records 39 of Set 6 | broome
# Processing Records 40 of Set 6 | robertson
# Processing Records 41 of Set 6 | fushun
# Processing Records 42 of Set 6 | isangel
# Processing Records 43 of Set 6 | bismarck
# Processing Records 44 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Records 45 of Set 6 | kyzyl-mazhalyk
# Processing Records 46 of Set 6 | itaborai
# Processing Records 47 of Set 6 | mount isa
# Processing Records 48 of Set 6 | mount gambier
# Processing Records 49 of Set 6 | petropavlovsk-kamchatskiy
# Processing Records 50 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Records 1 of Set 7 | tokur
# Processing Records 2 of Set 7 | mocajuba
# Processing Records 3 of Set 7 | itanhaem
# Processing Records 4 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Records 5 of Set 7 | axim
# Processing Records 6 of Set 7 | san pedro
# Processing Records 7 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Records 8 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Records 9 of Set 7 | shenjiamen
# Processing Records 10 of Set 7 | terney
# Processing Records 11 of Set 7 | vila velha
# Processing Records 12 of Set 7 | atambua
# Processing Records 13 of Set 7 | khartoum
# Processing Records 14 of Set 7 | leningradskiy
# Processing Records 15 of Set 7 | puerto el triunfo
# Processing Records 16 of Set 7 | high level
# Processing Records 17 of Set 7 | bilibino
# Processing Records 18 of Set 7 | barao de cocais
# Processing Records 19 of Set 7 | airai
# Processing Records 20 of Set 7 | yeniseysk
# Processing Records 21 of Set 7 | smithers
# Processing Records 22 of Set 7 | clyde river
# Processing Records 23 of Set 7 | opuwo
# Processing Records 24 of Set 7 | san isidro
# Processing Records 25 of Set 7 | aksu
# Processing Records 26 of Set 7 | maniitsoq
# Processing Records 27 of Set 7 | castelo do piaui
# Processing Records 28 of Set 7 | gat
# Processing Records 29 of Set 7 | ahipara
# Processing Records 30 of Set 7 | moree
# Processing Records 31 of Set 7 | haines junction
# Processing Records 32 of Set 7 | cockburn town
# Processing Records 33 of Set 7 | akyab
# Processing Records 34 of Set 7 | fortuna
# Processing Records 35 of Set 7 | amursk
# Processing Records 36 of Set 7 | itarema
# Processing Records 37 of Set 7 | inhambane
# Processing Records 38 of Set 7 | klaksvik
# Processing Records 39 of Set 7 | makakilo city
# Processing Records 40 of Set 7 | grand centre
# City not found. Skipping...
# Processing Records 41 of Set 7 | dubti
# Processing Records 42 of Set 7 | mae sai
# Processing Records 43 of Set 7 | sao filipe
# Processing Records 44 of Set 7 | freetown
# Processing Records 45 of Set 7 | miyako
# Processing Records 46 of Set 7 | dakar
# Processing Records 47 of Set 7 | mokrousovo
# Processing Records 48 of Set 7 | lerwick
# Processing Records 49 of Set 7 | saskylakh
# Processing Records 50 of Set 7 | samarai
# Processing Records 1 of Set 8 | baruun-urt
# Processing Records 2 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Records 3 of Set 8 | primorsk
# Processing Records 4 of Set 8 | kalaleh
# Processing Records 5 of Set 8 | warrington
# Processing Records 6 of Set 8 | half moon bay
# Processing Records 7 of Set 8 | hare bay
# Processing Records 8 of Set 8 | lagoa
# Processing Records 9 of Set 8 | baie-saint-paul
# Processing Records 10 of Set 8 | vilyuysk
# Processing Records 11 of Set 8 | parkes
# Processing Records 12 of Set 8 | mrirt
# City not found. Skipping...
# Processing Records 13 of Set 8 | umm kaddadah
# Processing Records 14 of Set 8 | san francisco
# Processing Records 15 of Set 8 | blairmore
# Processing Records 16 of Set 8 | ketchikan
# Processing Records 17 of Set 8 | polyarnyy
# Processing Records 18 of Set 8 | sabang
# Processing Records 19 of Set 8 | barkot
# Processing Records 20 of Set 8 | addi ugri
# City not found. Skipping...
# Processing Records 21 of Set 8 | la plata
# Processing Records 22 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Records 23 of Set 8 | hanzhong
# Processing Records 24 of Set 8 | midyat
# Processing Records 25 of Set 8 | cangucu
# Processing Records 26 of Set 8 | braslav
# City not found. Skipping...
# Processing Records 27 of Set 8 | kupang
# Processing Records 28 of Set 8 | vila franca do campo
# Processing Records 29 of Set 8 | jizan
# Processing Records 30 of Set 8 | sidi bin nur
# Processing Records 31 of Set 8 | yuli
# Processing Records 32 of Set 8 | chara
# Processing Records 33 of Set 8 | taywarah
# Processing Records 34 of Set 8 | hervey bay
# Processing Records 35 of Set 8 | konstantinovka
# Processing Records 36 of Set 8 | vostok
# Processing Records 37 of Set 8 | hualmay
# Processing Records 38 of Set 8 | tigil
# Processing Records 39 of Set 8 | gravatai
# Processing Records 40 of Set 8 | padang
# Processing Records 41 of Set 8 | alekseyevsk
# Processing Records 42 of Set 8 | asau
# Processing Records 43 of Set 8 | ambovombe
# Processing Records 44 of Set 8 | piripiri
# Processing Records 45 of Set 8 | gao
# Processing Records 46 of Set 8 | ancud
# Processing Records 47 of Set 8 | mozarlandia
# Processing Records 48 of Set 8 | alexandria
# Processing Records 49 of Set 8 | trincomalee
# Processing Records 50 of Set 8 | nome
# Processing Records 1 of Set 9 | okhotsk
# Processing Records 2 of Set 9 | imeni babushkina
# Processing Records 3 of Set 9 | hambantota
# Processing Records 4 of Set 9 | pevek
# Processing Records 5 of Set 9 | coahuayana
# Processing Records 6 of Set 9 | constitucion
# Processing Records 7 of Set 9 | tarakan
# Processing Records 8 of Set 9 | beringovskiy
# Processing Records 9 of Set 9 | santa isabel do rio negro
# Processing Records 10 of Set 9 | avera
# Processing Records 11 of Set 9 | ruidoso
# Processing Records 12 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Records 13 of Set 9 | lamar
# Processing Records 14 of Set 9 | tandil
# Processing Records 15 of Set 9 | porto walter
# Processing Records 16 of Set 9 | kidal
# Processing Records 17 of Set 9 | hokitika
# Processing Records 18 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Records 19 of Set 9 | pangnirtung
# Processing Records 20 of Set 9 | penzance
# Processing Records 21 of Set 9 | nouadhibou
# Processing Records 22 of Set 9 | road town
# Processing Records 23 of Set 9 | rungata
# City not found. Skipping...
# Processing Records 24 of Set 9 | urumqi
# Processing Records 25 of Set 9 | haukipudas
# Processing Records 26 of Set 9 | daura
# Processing Records 27 of Set 9 | fuxin
# Processing Records 28 of Set 9 | pijijiapan
# Processing Records 29 of Set 9 | krynychky
# Processing Records 30 of Set 9 | cancun
# Processing Records 31 of Set 9 | fort nelson
# Processing Records 32 of Set 9 | jalu
# Processing Records 33 of Set 9 | ailigandi
# Processing Records 34 of Set 9 | springbok
# Processing Records 35 of Set 9 | sioux lookout
# Processing Records 36 of Set 9 | san andres
# Processing Records 37 of Set 9 | martapura
# Processing Records 38 of Set 9 | gasa
# Processing Records 39 of Set 9 | pangoa
# Processing Records 40 of Set 9 | apac
# Processing Records 41 of Set 9 | mackay
# Processing Records 42 of Set 9 | talcahuano
# Processing Records 43 of Set 9 | kazuno
# Processing Records 44 of Set 9 | salamiyah
# Processing Records 45 of Set 9 | soyo
# Processing Records 46 of Set 9 | broken hill
# Processing Records 47 of Set 9 | pemberton
# Processing Records 48 of Set 9 | sakaiminato
# Processing Records 49 of Set 9 | bonavista
# Processing Records 50 of Set 9 | chemal
# Processing Records 1 of Set 10 | almaznyy
# Processing Records 2 of Set 10 | kutum
# Processing Records 3 of Set 10 | nanchang
# Processing Records 4 of Set 10 | vardo
# Processing Records 5 of Set 10 | porangatu
# Processing Records 6 of Set 10 | geraldton
# Processing Records 7 of Set 10 | valdivia
# Processing Records 8 of Set 10 | mweka
# Processing Records 9 of Set 10 | tutayev
# Processing Records 10 of Set 10 | tumut
# Processing Records 11 of Set 10 | shenzhen
# Processing Records 12 of Set 10 | umm lajj
# Processing Records 13 of Set 10 | vrangel
# Processing Records 14 of Set 10 | brindisi
# Processing Records 15 of Set 10 | rio gallegos
# Processing Records 16 of Set 10 | santiago de cao
# Processing Records 17 of Set 10 | vao
# Processing Records 18 of Set 10 | mahbubabad
# Processing Records 19 of Set 10 | yurimaguas
# Processing Records 20 of Set 10 | sinnamary
# Processing Records 21 of Set 10 | whitianga
# Processing Records 22 of Set 10 | marawi
# Processing Records 23 of Set 10 | humaita
# Processing Records 24 of Set 10 | lahr
# Processing Records 25 of Set 10 | cazaje
# City not found. Skipping...
# Processing Records 26 of Set 10 | malinyi
# Processing Records 27 of Set 10 | husavik
# Processing Records 28 of Set 10 | gazojak
# Processing Records 29 of Set 10 | corrales
# Processing Records 30 of Set 10 | toppenish
# Processing Records 31 of Set 10 | elk city
# Processing Records 32 of Set 10 | tautira
# Processing Records 33 of Set 10 | kasongo-lunda
# Processing Records 34 of Set 10 | am timan
# Processing Records 35 of Set 10 | dawei
# Processing Records 36 of Set 10 | dumas
# Processing Records 37 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Records 38 of Set 10 | comodoro rivadavia
# Processing Records 39 of Set 10 | bartica
# Processing Records 40 of Set 10 | khani
# Processing Records 41 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Records 42 of Set 10 | ulladulla
# Processing Records 43 of Set 10 | bjornevatn
# Processing Records 44 of Set 10 | torquay
# Processing Records 45 of Set 10 | muret
# Processing Records 46 of Set 10 | buraydah
# Processing Records 47 of Set 10 | bull savanna
# Processing Records 48 of Set 10 | huicheng
# Processing Records 49 of Set 10 | bay roberts
# Processing Records 50 of Set 10 | necochea
# Processing Records 1 of Set 11 | sao paulo de olivenca
# Processing Records 2 of Set 11 | tyukhtet
# Processing Records 3 of Set 11 | rumilly
# Processing Records 4 of Set 11 | arman
# Processing Records 5 of Set 11 | imbituba
# Processing Records 6 of Set 11 | phan rang
# City not found. Skipping...
# Processing Records 7 of Set 11 | nkhotakota
# Processing Records 8 of Set 11 | poum
# Processing Records 9 of Set 11 | camacha
# Processing Records 10 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Records 11 of Set 11 | mirzapur
# Processing Records 12 of Set 11 | azimur
# City not found. Skipping...
# Processing Records 13 of Set 11 | buta
# Processing Records 14 of Set 11 | molina
# Processing Records 15 of Set 11 | kismayo
# Processing Records 16 of Set 11 | lokomotivnyy
# Processing Records 17 of Set 11 | lorengau
# Processing Records 18 of Set 11 | jhargram
# Processing Records 19 of Set 11 | edea
# Processing Records 20 of Set 11 | foumban
# Processing Records 21 of Set 11 | torbay
# Processing Records 22 of Set 11 | cap malheureux
# Processing Records 23 of Set 11 | aasiaat
# Processing Records 24 of Set 11 | barawe
# City not found. Skipping...
# Processing Records 25 of Set 11 | kieta
# Processing Records 26 of Set 11 | coquimbo
# Processing Records 27 of Set 11 | ponta delgada
# Processing Records 28 of Set 11 | waipawa
# Processing Records 29 of Set 11 | pirai do sul
# Processing Records 30 of Set 11 | ulaangom
# Processing Records 31 of Set 11 | puerto escondido
# Processing Records 32 of Set 11 | pryozerne
# Processing Records 33 of Set 11 | banmo
# City not found. Skipping...
# Processing Records 34 of Set 11 | sergeyevka
# Processing Records 35 of Set 11 | maldonado
# Processing Records 36 of Set 11 | chilca
# Processing Records 37 of Set 11 | pinotepa nacional
# Processing Records 38 of Set 11 | maceio
# Processing Records 39 of Set 11 | frankfort
# Processing Records 40 of Set 11 | tabulbah
# City not found. Skipping...
# Processing Records 41 of Set 11 | alta floresta
# Processing Records 42 of Set 11 | brejo
# Processing Records 43 of Set 11 | oceanside
# Processing Records 44 of Set 11 | vestmannaeyjar
# Processing Records 45 of Set 11 | fernandez
# Processing Records 46 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Records 47 of Set 11 | preston
# Processing Records 48 of Set 11 | rundu
# Processing Records 49 of Set 11 | la orilla
# Processing Records 50 of Set 11 | matamoros
# Processing Records 1 of Set 12 | yulara
# Processing Records 2 of Set 12 | melilla
# Processing Records 3 of Set 12 | chunoyar
# Processing Records 4 of Set 12 | coihaique
# Processing Records 5 of Set 12 | perth
# Processing Records 6 of Set 12 | zavyalovo
# Processing Records 7 of Set 12 | dabakala
# Processing Records 8 of Set 12 | erenhot
# Processing Records 9 of Set 12 | richards bay
# Processing Records 10 of Set 12 | oktyabrskiy
# Processing Records 11 of Set 12 | carbonia
# Processing Records 12 of Set 12 | ambagarh chauki
# Processing Records 13 of Set 12 | cairns
# Processing Records 14 of Set 12 | severo-yeniseyskiy
# Processing Records 15 of Set 12 | havre-saint-pierre
# Processing Records 16 of Set 12 | tual
# Processing Records 17 of Set 12 | tera
# Processing Records 18 of Set 12 | las choapas
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Cape Town -33.93   18.42     68.00        72          20       27.51
# 1            Hovd  48.01   91.64      2.91        58          97        9.78
# 2          Hobart -42.88  147.33     66.00        44          75        5.82
# 3    Marsa Matruh  31.35   27.25     51.80        87          40        6.93
# 4           Vaini -21.20 -175.20     82.40        88          90       11.41
# 5       Esperance -33.87  121.90     62.60        88          90       14.99
# 6     New Norfolk -42.78  147.06     66.00        44          75        5.82
# 7  Harbour Breton  47.48  -55.80     14.59        78         100       45.14
# 8    Punta Arenas -53.15  -70.92     53.60        58          75       38.03
# 9       Mahebourg -20.41   57.70     80.60        83          40       11.41
#
#    Rain (inches, last 3 hrs)  Snow (inches, last 3 hrs)  \
# 0                        0.0                       0.00
# 1                        0.0                       0.00
# 2                        0.0                       0.00
# 3                        0.0                       0.00
# 4                        0.0                       0.00
# 5                        0.0                       0.00
# 6                        0.0                       0.00
# 7                        0.0                       0.13
# 8                        0.0                       0.00
# 9                        0.0                       0.00
#
#   Current Weather Description Country                 Date
# 0                  few clouds      ZA  2020-01-17 23:44:22
# 1             overcast clouds      MN  2020-01-17 23:46:24
# 2               broken clouds      AU  2020-01-17 23:43:47
# 3            scattered clouds      EG  2020-01-17 23:46:26
# 4             overcast clouds      TO  2020-01-17 23:43:55
# 5             overcast clouds      AU  2020-01-17 23:46:27
# 6               broken clouds      AU  2020-01-17 23:44:59
# 7                  light snow      CA  2020-01-17 23:46:29
# 8               broken clouds      CL  2020-01-17 23:43:46
# 9            scattered clouds      MU  2020-01-17 23:43:54

# %%
# Reorder Columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Weather Description", "Rain (inches, last 3 hrs)", "Snow (inches, last 3 hrs)"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0       Cape Town      ZA  2020-01-17 23:44:22 -33.93   18.42     68.00
# 1            Hovd      MN  2020-01-17 23:46:24  48.01   91.64      2.91
# 2          Hobart      AU  2020-01-17 23:43:47 -42.88  147.33     66.00
# 3    Marsa Matruh      EG  2020-01-17 23:46:26  31.35   27.25     51.80
# 4           Vaini      TO  2020-01-17 23:43:55 -21.20 -175.20     82.40
# 5       Esperance      AU  2020-01-17 23:46:27 -33.87  121.90     62.60
# 6     New Norfolk      AU  2020-01-17 23:44:59 -42.78  147.06     66.00
# 7  Harbour Breton      CA  2020-01-17 23:46:29  47.48  -55.80     14.59
# 8    Punta Arenas      CL  2020-01-17 23:43:46 -53.15  -70.92     53.60
# 9       Mahebourg      MU  2020-01-17 23:43:54 -20.41   57.70     80.60
#
#    Humidity  Cloudiness  Wind Speed Current Weather Description  \
# 0        72          20       27.51                  few clouds
# 1        58          97        9.78             overcast clouds
# 2        44          75        5.82               broken clouds
# 3        87          40        6.93            scattered clouds
# 4        88          90       11.41             overcast clouds
# 5        88          90       14.99             overcast clouds
# 6        44          75        5.82               broken clouds
# 7        78         100       45.14                  light snow
# 8        58          75       38.03               broken clouds
# 9        83          40       11.41            scattered clouds
#
#    Rain (inches, last 3 hrs)  Snow (inches, last 3 hrs)
# 0                        0.0                       0.00
# 1                        0.0                       0.00
# 2                        0.0                       0.00
# 3                        0.0                       0.00
# 4                        0.0                       0.00
# 5                        0.0                       0.00
# 6                        0.0                       0.00
# 7                        0.0                       0.13
# 8                        0.0                       0.00
# 9                        0.0                       0.00

# %%
# Create the output file (CSV)
output_data_file = "weather_data/weatherpy_challenge.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
